# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from scipy.stats import poisson
from scipy.stats import *

# %%
data = []
for i in range(20):
	x = 6
	data.append(poisson.pmf(i,10))




plt.figure(figsize=(5,5))
plt.plot(range(20),data)

# %%
#5 people buy bubble tea in an hour
arriving_time = np.random.uniform(low=0,high=60,size=5)
arriving_time = sorted(arriving_time)
print(arriving_time)

intervals = []
for i in range(len(arriving_time) -1):
	intervals.append((arriving_time[i+1] - arriving_time[i]))

# expon.pdf()
# Out:
# [21.066089438661763, 34.51787333273165, 42.46146258274428, 43.94622189385389, 53.07551438271745]

# %%
# if avg wait time is 12 mins, what is prob of waiting 5 mins
expon.pdf(5, scale=12)
# Out:
# 0.054936719183370314

# %%
#avg wait time is 10 mins, what is prob of waiting 15 mins?
expon.cdf(10, scale=10)
# Out:
# 0.6321205588285577

# %%
#avg wait time is 7 days, prob of waiting less than 10 days
expon.cdf(10, scale=7)
# Out:
# 0.7603489635582242

# %%
#avg 30 goals in 48 mins, probability of time between goals exceeding 3.6 mins
1 - expon.cdf(3.6, scale=48/30)
# Out:
# 0.10539922456186435
